# %%
import tensorflow as tf

# %%
# 匯入 Fashion MNIST 女人10個用品 訓練資料
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
# 訓練/測試資料的 X/y 維度
x_train.shape, y_train.shape,x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# 特徵縮放，使用常態化(Normalization)，公式 = (x - min) / (max - min)
x_train_norm, x_test_norm = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ## neural_count = 128

# %%
# 建立模型
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 設定優化器(optimizer)、損失函數(loss)、效能衡量指標(metrics)的類別
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 訓練
history = model.fit(x_train_norm, y_train, epochs=5, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 4s 84us/sample - loss: 0.5539 - accuracy: 0.8039 - val_loss: 0.4229 - val_accuracy: 0.8499
# Epoch 2/5
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.4089 - accuracy: 0.8516 - val_loss: 0.3752 - val_accuracy: 0.8645
# Epoch 3/5
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.3724 - accuracy: 0.8628 - val_loss: 0.3587 - val_accuracy: 0.8687
# Epoch 4/5
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.3494 - accuracy: 0.8706 - val_loss: 0.3520 - val_accuracy: 0.8711
# Epoch 5/5
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.3316 - accuracy: 0.8776 - val_loss: 0.3322 - val_accuracy: 0.8798

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [0.3598124606370926, 0.8691]

# %% [markdown]
# ## neural_count=512

# %%
# 建立模型
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 設定優化器(optimizer)、損失函數(loss)、效能衡量指標(metrics)的類別
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 訓練
history = model.fit(x_train_norm, y_train, epochs=5, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 4s 83us/sample - loss: 0.5120 - accuracy: 0.8175 - val_loss: 0.4238 - val_accuracy: 0.8396
# Epoch 2/5
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3952 - accuracy: 0.8567 - val_loss: 0.3888 - val_accuracy: 0.8577
# Epoch 3/5
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3590 - accuracy: 0.8685 - val_loss: 0.3713 - val_accuracy: 0.8655
# Epoch 4/5
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3358 - accuracy: 0.8758 - val_loss: 0.3361 - val_accuracy: 0.8781
# Epoch 5/5
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.3198 - accuracy: 0.8817 - val_loss: 0.3429 - val_accuracy: 0.8748

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [0.3721928252339363, 0.8652]

# %% [markdown]
# ## neural_count=32

# %%
# 建立模型
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 設定優化器(optimizer)、損失函數(loss)、效能衡量指標(metrics)的類別
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 訓練
history = model.fit(x_train_norm, y_train, epochs=5, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.6883 - accuracy: 0.7605 - val_loss: 0.4788 - val_accuracy: 0.8289
# Epoch 2/5
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.4902 - accuracy: 0.8261 - val_loss: 0.4300 - val_accuracy: 0.8423
# Epoch 3/5
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.4525 - accuracy: 0.8369 - val_loss: 0.4028 - val_accuracy: 0.8554
# Epoch 4/5
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.4295 - accuracy: 0.8447 - val_loss: 0.3892 - val_accuracy: 0.8566
# Epoch 5/5
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.4129 - accuracy: 0.8500 - val_loss: 0.3790 - val_accuracy: 0.8633

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [0.4038283855438232, 0.8534]
