# %%
import tensorflow as tf

# %%
# 匯入 Fashion MNIST 女人10個用品 訓練資料
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
# 訓練/測試資料的 X/y 維度
x_train.shape, y_train.shape,x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# 特徵縮放，使用常態化(Normalization)，公式 = (x - min) / (max - min)
x_train_norm, x_test_norm = x_train / 255.0, x_test / 255.0

# %%
# 建立模型
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 設定優化器(optimizer)、損失函數(loss)、效能衡量指標(metrics)的類別
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## epochs = 5

# %%
# 訓練
history = model.fit(x_train_norm, y_train, epochs=5, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.5561 - accuracy: 0.8045 - val_loss: 0.4134 - val_accuracy: 0.8486
# Epoch 2/5
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.4127 - accuracy: 0.8506 - val_loss: 0.3714 - val_accuracy: 0.8658
# Epoch 3/5
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.3769 - accuracy: 0.8636 - val_loss: 0.3555 - val_accuracy: 0.8720
# Epoch 4/5
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.3506 - accuracy: 0.8710 - val_loss: 0.3474 - val_accuracy: 0.8749
# Epoch 5/5
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.3349 - accuracy: 0.8772 - val_loss: 0.3425 - val_accuracy: 0.8750

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test, verbose=0)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [0.36941616983413694, 0.8686]

# %% [markdown]
# ## epochs = 10

# %%
# 訓練
history = model.fit(x_train_norm, y_train, epochs=10, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3231 - accuracy: 0.8797 - val_loss: 0.3341 - val_accuracy: 0.8812
# Epoch 2/10
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3087 - accuracy: 0.8852 - val_loss: 0.3218 - val_accuracy: 0.8840
# Epoch 3/10
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2999 - accuracy: 0.8877 - val_loss: 0.3237 - val_accuracy: 0.8827
# Epoch 4/10
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.2893 - accuracy: 0.8908 - val_loss: 0.3223 - val_accuracy: 0.8831
# Epoch 5/10
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2800 - accuracy: 0.8965 - val_loss: 0.3331 - val_accuracy: 0.8783
# Epoch 6/10
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2765 - accuracy: 0.8953 - val_loss: 0.3142 - val_accuracy: 0.8848
# Epoch 7/10
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2715 - accuracy: 0.8984 - val_loss: 0.3241 - val_accuracy: 0.8873
# Epoch 8/10
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.2668 - accuracy: 0.8993 - val_loss: 0.3245 - val_accuracy: 0.8861
# Epoch 9/10
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2584 - accuracy: 0.9030 - val_loss: 0.3277 - val_accuracy: 0.8873
# Epoch 10/10
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.2526 - accuracy: 0.9036 - val_loss: 0.3163 - val_accuracy: 0.8915

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test, verbose=0)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [0.3419372635900974, 0.8825]

# %% [markdown]
# ## epochs = 20

# %%
# 訓練
history = model.fit(x_train_norm, y_train, epochs=20, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.2503 - accuracy: 0.9062 - val_loss: 0.3281 - val_accuracy: 0.8822
# Epoch 2/20
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.2447 - accuracy: 0.9093 - val_loss: 0.3131 - val_accuracy: 0.8896
# Epoch 3/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.2387 - accuracy: 0.9094 - val_loss: 0.3163 - val_accuracy: 0.8929
# Epoch 4/20
# 48000/48000 [==============================] - 4s 78us/sample - loss: 0.2357 - accuracy: 0.9093 - val_loss: 0.3257 - val_accuracy: 0.8875
# Epoch 5/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2333 - accuracy: 0.9114 - val_loss: 0.3326 - val_accuracy: 0.8868
# Epoch 6/20
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.2287 - accuracy: 0.9134 - val_loss: 0.3364 - val_accuracy: 0.8928
# Epoch 7/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2263 - accuracy: 0.9135 - val_loss: 0.3274 - val_accuracy: 0.8916
# Epoch 8/20
# 48000/48000 [==============================] - 4s 77us/sample - loss: 0.2231 - accuracy: 0.9150 - val_loss: 0.3309 - val_accuracy: 0.8923
# Epoch 9/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2189 - accuracy: 0.9158 - val_loss: 0.3274 - val_accuracy: 0.8944
# Epoch 10/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2188 - accuracy: 0.9184 - val_loss: 0.3241 - val_accuracy: 0.8935
# Epoch 11/20
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.2110 - accuracy: 0.9195 - val_loss: 0.3331 - val_accuracy: 0.8929
# Epoch 12/20
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.2094 - accuracy: 0.9201 - val_loss: 0.3408 - val_accuracy: 0.8881
# Epoch 13/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2081 - accuracy: 0.9199 - val_loss: 0.3305 - val_accuracy: 0.8947
# Epoch 14/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2049 - accuracy: 0.9222 - val_loss: 0.3329 - val_accuracy: 0.8902
# Epoch 15/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.2004 - accuracy: 0.9230 - val_loss: 0.3391 - val_accuracy: 0.8936
# Epoch 16/20
# 48000/48000 [==============================] - 4s 76us/sample - loss: 0.2002 - accuracy: 0.9238 - val_loss: 0.3412 - val_accuracy: 0.8923
# Epoch 17/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.1968 - accuracy: 0.9246 - val_loss: 0.3330 - val_accuracy: 0.8947
# Epoch 18/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.1938 - accuracy: 0.9262 - val_loss: 0.3548 - val_accuracy: 0.8885
# Epoch 19/20
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.1908 - accuracy: 0.9267 - val_loss: 0.3405 - val_accuracy: 0.8903
# Epoch 20/20
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.1918 - accuracy: 0.9264 - val_loss: 0.3487 - val_accuracy: 0.8972

# %%
# 評估，打分數
score=model.evaluate(x_test_norm, y_test, verbose=0)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [0.3865271923899651, 0.8851]
